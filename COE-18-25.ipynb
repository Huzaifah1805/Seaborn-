# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(df.shape)
# Out:
# (244, 7)

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
print(df.describe())
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [markdown]
# insights

# %% [markdown]
# **Insights**
# df.info()
# information of dataset ,how many rows and columns
# df.describe
# same as info
# df.describe()
# statistical information
# df.dtypes
# datypesof a dataset.
# df.shape
# it tells about dimension of dataset eg:-1D or 2D

# %% [markdown]
# **Insights**
# total records=244 rows, 7 columns
# variable=
# numeric:- total_bill,tip,size
# category:-sex,smoker,day,time
# Total Bill
# Most customers spend between ₹15-₹28
# tip
# minimum=1.50
# maximum=12.00
# most customers gives tips between 2.50- 5.00
# groupsize
# most of them comes in (2-4) peoples
# gender
# most common gender= female
# females= 130
# smoker
# most of them are smokers
# smoker=145

# %% [markdown]
# # **New Section**

# %%
print(df.isnull().sum())
#isnull().sum()
#this is used in pandas for checking null values in dataset.
#total_bill has 0
#tip           0
#sex           0
#smoker        0
#day           0
#time          0
#size          0
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
print(df.isin(['sex']))
#isin return a boolean series if there is a null value it returns true or false if not
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
print(df.dropna())
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
(50/244)*100
# Out:
# 20.491803278688526

# %%
data=sns.load_dataset('titanic')

# %%
print(data.isna().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
print(data.shape[0])
# Out:
# 891

# %%
(2/891)*100
# Out:
# 0.22446689113355783

# %%
(data.isnull().sum()/data.shape[0])*100
#it used to calculate the percentage of null values in a dataset
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
data.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
((data.shape[0]-data.dropna().shape[0])/data.shape[0])*100
#claculating the null percentage of a dataset
# Out:
# 79.57351290684625

# %%
data['embark_town'].fillna(data['embark_town'].mode()[0],inplace=True)
data['embarked'].fillna(data['embarked'].mode()[0],inplace=True)
data['deck'].fillna(data['deck'].mode()[0],inplace=True)
data['age'].fillna(data['age'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-3159022007.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['embark_town'].fillna(data['embark_town'].mode()[0],inplace=True)
# /tmp/ipython-input-3159022007.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         891 non-null    category
#  12  embark_town  891 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['age'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['pclass'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['sex'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['sibsp'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['parch'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['fare'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['alone'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(x=data['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=data['sex'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=data['age'])
plt.show()

# %%
#bivariate Analysis

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['survived'],hue=data['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['pclass'],hue=data['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['sibsp'],hue=data['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['age'], hue=data['embarked'], kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['fare'],hue=data['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['pclass'],hue=data['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['age'],hue=data['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['parch'],hue=data['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['survived'],hue=data['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['sibsp'],hue=data['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['fare'],hue=data['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['parch'],hue=data['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['sibsp'],hue=data['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['age'],hue=data['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['pclass'],hue=data['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['survived'],hue=data['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['fare'],hue=data['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['parch'],hue=data['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=data['class'],hue=data['alive'],kde=True)
plt.show()
